# %% [markdown]
# # Применение Computer Vision в задаче медицинской диагностики
#
# ---

# %% [markdown]
# ## Датасет для обучения сети был взят с kaggle, он содержит рентген-снимки детей в возрасте до 5 лет.

# %% [markdown]
# ## Для обучения нейросети (а если быть более точным 5-и экземпляров) я использовал сервис Google Colab. Здесь же находятся лишь модель и 5 обученных весов. Процесс обучения показывать я не буду, так как он занимает больше 30-и минут на одну модель. Снимок проходит сначала через 5 моделей, их предсказания объединяются в единий "слепок", который затем отправляется полносвязой сети, обученной для анализа уже предсказанных данных. Полносвязанная сеть на основе "слепка" уже делает свои предсказания и вывод. Точность всей конструкции составляет 93%.

# %% [markdown]
# ### Здесь находятся все необходимые импорты.

# %%
import os
import numpy as np
import cv2
from keras.models import Model, Sequential
from keras.layers import Input, Dense, Flatten, Dropout, BatchNormalization
from keras.layers import Conv2D, SeparableConv2D, MaxPool2D
from sklearn.model_selection import train_test_split
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Этот фрагмент — загрузка в оперативную память данных для обучения. Я перемешиваю данные, так как изначально они идут в последовательном порядке (сначала обычные снимки, затем с пневмонией)

# %%
path = os.getcwd() + '\data\chest_xray\\' 

train_data = []
train_labels = []

for cond in ['\\NORMAL\\', '\\PNEUMONIA\\']:
    for img in (os.listdir(path + 'train' + cond)):
          img = cv2.imread(path+'train'+cond+img, cv2.IMREAD_COLOR)
          img = cv2.resize(img, (150, 150), cv2.INTER_AREA)
          img = img.astype('float32') / 255
          if cond=='\\NORMAL\\':
              label = 0
          elif cond=='\\PNEUMONIA\\':
              label = 1

          train_data.append(img) 
          train_labels.append(label)
        
train_data = np.array(train_data)
train_labels = np.array(train_labels)
train_data, train_labels = shuffle(train_data, train_labels)

# %% [markdown]
# ### Здесь происходит загрузка данных для тестирование сети

# %%
test_data = []
test_labels = []

for cond in ['\\NORMAL\\', '\\PNEUMONIA\\']:
      for img in (os.listdir(path + 'test' + cond)):
          img = cv2.imread(path+'test'+cond+img, cv2.IMREAD_COLOR)
          img = cv2.resize(img, (150, 150), cv2.INTER_AREA)
          img = img.astype('float32') / 255
          if cond=='\\NORMAL\\':
              label = 0
          elif cond=='\\PNEUMONIA\\':
              label = 1
              
          test_data.append(img)
          test_labels.append(label)
        
test_data = np.array(test_data)
test_labels = np.array(test_labels)

# %% [markdown]
# ### Как видно всего в датасете 5840 снимков. 5126 из них в обучающем наборе, 624 в тестирующем

# %%
print(len(test_data))
print(len(train_data))
# Out:
# 624
# 5216

# %% [markdown]
# ### Здесь находится функция для создания самой модели. Её архитектура немного напоминает VGG16, но она менее глубокая (так как датасет совсем небольшой, это позволяет уменьшить переобучаемость) и состоит из 5 convolution-блоков, начиная с 16х3х3 и затем увеличивая размерность с каждым разом в 2 раза. Затем после 5-и свёрточных блоков идёт полносвязный, состоящий из 3-ёх скрытых слоёв и одного выходного. В качестве активации у всех слоёв используется ReLU, у последнего — сигмоида.

# %%
def create_model():
  inputs = Input(shape=(150, 150, 3))

  # Первый блок свёртки
  x = Conv2D(filters=16, kernel_size=(3, 3), activation='relu', padding='same')(inputs)
  x = Conv2D(filters=16, kernel_size=(3, 3), activation='relu', padding='same')(x)
  x = MaxPool2D(pool_size=(2, 2))(x)

  # Второй блок свёртки
  x = SeparableConv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same')(x)
  x = SeparableConv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same')(x)
  x = BatchNormalization()(x)
  x = MaxPool2D(pool_size=(2, 2))(x)

  # Третий блок свёртки
  x = SeparableConv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same')(x)
  x = SeparableConv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same')(x)
  x = BatchNormalization()(x)
  x = MaxPool2D(pool_size=(2, 2))(x)

  # Четвёртый блок свёртки
  x = SeparableConv2D(filters=128, kernel_size=(3, 3), activation='relu', padding='same')(x)
  x = SeparableConv2D(filters=128, kernel_size=(3, 3), activation='relu', padding='same')(x)
  x = BatchNormalization()(x)
  x = MaxPool2D(pool_size=(2, 2))(x)
  x = Dropout(rate=0.2)(x)

  # Пятый блок свёртки
  x = SeparableConv2D(filters=256, kernel_size=(3, 3), activation='relu', padding='same')(x)
  x = SeparableConv2D(filters=256, kernel_size=(3, 3), activation='relu', padding='same')(x)
  x = BatchNormalization()(x)
  x = MaxPool2D(pool_size=(2, 2))(x)
  x = Dropout(rate=0.2)(x)

  # Полносвязный слой
  x = Flatten()(x)
  x = Dense(units=512, activation='relu')(x)
  x = Dropout(rate=0.7)(x)
  x = Dense(units=128, activation='relu')(x)
  x = Dropout(rate=0.5)(x)
  x = Dense(units=64, activation='relu')(x)
  x = Dropout(rate=0.3)(x)

  # Output layer
  output = Dense(units=1, activation='sigmoid')(x)

  # Creating model and compiling
  model = Model(inputs=inputs, outputs=output)
  model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
  return model

# %% [markdown]
# ### Это же модель, которая суммирует предсказания 5-и моделей, со структорой выше. Она полностью полносвязная и состоит из 5-и входных нейронов, двух скрытых слоёв и одного выходного.

# %%
def create_top_model():
    #Simple fully-connected model for final decision
    inputs = Input(shape=(5, ))
    
    x = Dense(units=512, activation='relu')(inputs)
    x = Dense(units=256, activation='relu')(x)
    
    output = Dense(units=1, activation='sigmoid')(x)
    
    model = Model(inputs=inputs, outputs=output)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    
    return model

# %%
checkpoint = ModelCheckpoint(filepath='top_model.hdf5', save_best_only=True, save_weights_only=True)
lr_reduce = ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=2, verbose=2, mode='max')
early_stop = EarlyStopping(monitor='val_loss', min_delta=0.1, patience=1, mode='min')

# %% [markdown]
# ### Так как обучение велось непосредственно в Colab, здесь находится лишь модуль с загрузкой всех пяти моделей

# %%
models_path = '\\models\\'

models = [create_model() for i in range(5)]
for i in range(5):
  models[i].load_weights(os.getcwd() + models_path + 'best_weights-model' + str(i) + '.hdf5', verbose=0)

# %% [markdown]
# ### Здесь находится функция для создания "слепка" из предсказаний моделей. Мы совмещаем предсказания 5-и моделей, для дальнейшего обучения полносвязной модели

# %%
def stacked_dataset(members, inputX):
	stackX = None
	for model in members:
		# Предсказания
		yhat = model.predict(inputX, verbose=0)
		# Стакаем предсказания [строки, модели, вероятности]
		if stackX is None:
			stackX = yhat
		else:
			stackX = np.dstack((stackX, yhat))
	# Уменьшаем размерность до [строки, модели х вероятности]
	stackX = stackX.reshape((stackX.shape[0], stackX.shape[1]*stackX.shape[2]))
	return stackX

# %% [markdown]
# ### Здесь мы обучаем саму полносвязную модель, используя callback-и для понижения скорости обучения и сохранения весов лучшей модели

# %%
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from catboost import CatBoostClassifier
from sklearn.linear_model import LogisticRegression

def fit_model(members, inputX, inputy):
	# Получаем стаканный датасет
	stackedX = stacked_dataset(members, inputX)
	# Обучаем модельку
	model = create_top_model()
	model.fit(stackedX, inputy, epochs=100, callbacks=[checkpoint, lr_reduce], validation_split=0.2)
	return model

model = fit_model(models, train_data, train_labels)
# Out:
# Train on 4172 samples, validate on 1044 samples
# Epoch 1/100
# 4172/4172 [==============================] - 1s 153us/step - loss: 0.1586 - accuracy: 0.9331 - val_loss: 0.1035 - val_accuracy: 0.9655
# Epoch 2/100
# 4172/4172 [==============================] - 1s 121us/step - loss: 0.0935 - accuracy: 0.9703 - val_loss: 0.1032 - val_accuracy: 0.9665
# Epoch 3/100
# 4172/4172 [==============================] - 0s 115us/step - loss: 0.0933 - accuracy: 0.9703 - val_loss: 0.0966 - val_accuracy: 0.9674
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# Epoch 4/100
# 4172/4172 [==============================] - 0s 114us/step - loss: 0.0895 - accuracy: 0.9710 - val_loss: 0.0955 - val_accuracy: 0.9674
# Epoch 5/100
# 4172/4172 [==============================] - 0s 107us/step - loss: 0.0887 - accuracy: 0.9722 - val_loss: 0.0965 - val_accuracy: 0.9674
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# Epoch 6/100
# 4172/4172 [==============================] - 1s 123us/step - loss: 0.0881 - accuracy: 0.9717 - val_loss: 0.0951 - val_accuracy: 0.9684
# Epoch 7/100
# 4172/4172 [==============================] - 0s 118us/step - loss: 0.0879 - accuracy: 0.9729 - val_loss: 0.0948 - val_accuracy: 0.9665
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# Epoch 8/100
# 4172/4172 [==============================] - 1s 122us/step - loss: 0.0875 - accuracy: 0.9734 - val_loss: 0.0948 - val_accuracy: 0.9674
# Epoch 9/100
# 4172/4172 [==============================] - 1s 121us/step - loss: 0.0874 - accuracy: 0.9734 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# Epoch 10/100
# 4172/4172 [==============================] - 1s 122us/step - loss: 0.0873 - accuracy: 0.9734 - val_loss: 0.0948 - val_accuracy: 0.9665
# Epoch 11/100
# 4172/4172 [==============================] - 0s 110us/step - loss: 0.0873 - accuracy: 0.9732 - val_loss: 0.0948 - val_accuracy: 0.9665
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# Epoch 12/100
# 4172/4172 [==============================] - 0s 118us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0948 - val_accuracy: 0.9665
# Epoch 13/100
# 4172/4172 [==============================] - 0s 118us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 7.289999985005124e-07.
# Epoch 14/100
# 4172/4172 [==============================] - 1s 123us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 15/100
# 4172/4172 [==============================] - 0s 109us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 2.1870000637136398e-07.
# Epoch 16/100
# 4172/4172 [==============================] - 0s 117us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 17/100
# 4172/4172 [==============================] - 1s 121us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 6.561000276406048e-08.
# Epoch 18/100
# 4172/4172 [==============================] - 0s 107us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 19/100
# 4172/4172 [==============================] - 1s 121us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 1.9683000829218145e-08.
# Epoch 20/100
# 4172/4172 [==============================] - 0s 117us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 21/100
# 4172/4172 [==============================] - 0s 118us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 5.904900035602622e-09.
# Epoch 22/100
# 4172/4172 [==============================] - 0s 117us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 23/100
# 4172/4172 [==============================] - 0s 116us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1.7714700373261393e-09.
# Epoch 24/100
# 4172/4172 [==============================] - 0s 110us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 25/100
# 4172/4172 [==============================] - 0s 117us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 5.314410245205181e-10.
# Epoch 26/100
# 4172/4172 [==============================] - 0s 115us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 27/100
# 4172/4172 [==============================] - 0s 119us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 1.5943230069481729e-10.
# Epoch 28/100
# 4172/4172 [==============================] - 0s 108us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 29/100
# 4172/4172 [==============================] - 0s 115us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 4.7829690208445185e-11.
# Epoch 30/100
# 4172/4172 [==============================] - 0s 118us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 31/100
# 4172/4172 [==============================] - 0s 109us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 1.434890747886719e-11.
# Epoch 32/100
# 4172/4172 [==============================] - 1s 121us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 33/100
# 4172/4172 [==============================] - 0s 111us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 4.304672243660157e-12.
# Epoch 34/100
# 4172/4172 [==============================] - 0s 120us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 35/100
# 4172/4172 [==============================] - 0s 118us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 1.2914016210563428e-12.
# Epoch 36/100
# 4172/4172 [==============================] - 1s 121us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 37/100
# 4172/4172 [==============================] - 0s 114us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 3.874204993273289e-13.
# Epoch 38/100
# 4172/4172 [==============================] - 1s 122us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 39/100
# 4172/4172 [==============================] - 1s 122us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 1.162261530508052e-13.
# Epoch 40/100
# 4172/4172 [==============================] - 0s 118us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 41/100
# 4172/4172 [==============================] - 0s 109us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 3.4867844288938296e-14.
# Epoch 42/100
# 4172/4172 [==============================] - 0s 107us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 43/100
# 4172/4172 [==============================] - 0s 116us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 1.0460353083393582e-14.
# Epoch 44/100
# 4172/4172 [==============================] - 0s 105us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 45/100
# 4172/4172 [==============================] - 0s 117us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 3.138105874196098e-15.
# Epoch 46/100
# 4172/4172 [==============================] - 0s 118us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 47/100
# 4172/4172 [==============================] - 1s 120us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 9.414317622588293e-16.
# Epoch 48/100
# 4172/4172 [==============================] - 0s 117us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 49/100
# 4172/4172 [==============================] - 0s 118us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 2.8242954138314303e-16.
# Epoch 50/100
# 4172/4172 [==============================] - 0s 116us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 51/100
# 4172/4172 [==============================] - 1s 120us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 8.472885923856935e-17.
# Epoch 52/100
# 4172/4172 [==============================] - 0s 111us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 53/100
# 4172/4172 [==============================] - 0s 114us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 2.541865737452411e-17.
# Epoch 54/100
# 4172/4172 [==============================] - 0s 117us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 55/100
# 4172/4172 [==============================] - 0s 116us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00055: ReduceLROnPlateau reducing learning rate to 7.62559741088058e-18.
# Epoch 56/100
# 4172/4172 [==============================] - 0s 117us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 57/100
# 4172/4172 [==============================] - 0s 114us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 2.2876793225258477e-18.
# Epoch 58/100
# 4172/4172 [==============================] - 0s 117us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 59/100
# 4172/4172 [==============================] - 0s 111us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 6.863037719423359e-19.
# Epoch 60/100
# 4172/4172 [==============================] - 1s 121us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 61/100
# 4172/4172 [==============================] - 0s 109us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 2.0589113778655536e-19.
# Epoch 62/100
# 4172/4172 [==============================] - 0s 117us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 63/100
# 4172/4172 [==============================] - 1s 122us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 6.176734056048479e-20.
# Epoch 64/100
# 4172/4172 [==============================] - 0s 120us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 65/100
# 4172/4172 [==============================] - 1s 124us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00065: ReduceLROnPlateau reducing learning rate to 1.8530202168145436e-20.
# Epoch 66/100
# 4172/4172 [==============================] - 0s 116us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 67/100
# 4172/4172 [==============================] - 0s 116us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00067: ReduceLROnPlateau reducing learning rate to 5.559060844314087e-21.
# Epoch 68/100
# 4172/4172 [==============================] - 0s 112us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 69/100
# 4172/4172 [==============================] - 0s 117us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 1.667718253294226e-21.
# Epoch 70/100
# 4172/4172 [==============================] - 0s 107us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 71/100
# 4172/4172 [==============================] - 1s 122us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00071: ReduceLROnPlateau reducing learning rate to 5.003154881051713e-22.
# Epoch 72/100
# 4172/4172 [==============================] - 1s 121us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 73/100
# 4172/4172 [==============================] - 1s 121us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00073: ReduceLROnPlateau reducing learning rate to 1.500946434023255e-22.
# Epoch 74/100
# 4172/4172 [==============================] - 0s 114us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 75/100
# 4172/4172 [==============================] - 0s 117us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00075: ReduceLROnPlateau reducing learning rate to 4.5028393778004124e-23.
# Epoch 76/100
# 4172/4172 [==============================] - 0s 109us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 77/100
# 4172/4172 [==============================] - 0s 117us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00077: ReduceLROnPlateau reducing learning rate to 1.350851851205447e-23.
# Epoch 78/100
# 4172/4172 [==============================] - 0s 111us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 79/100
# 4172/4172 [==============================] - 1s 120us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 4.05255564827965e-24.
# Epoch 80/100
# 4172/4172 [==============================] - 0s 110us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 81/100
# 4172/4172 [==============================] - 0s 112us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00081: ReduceLROnPlateau reducing learning rate to 1.2157666708180678e-24.
# Epoch 82/100
# 4172/4172 [==============================] - 0s 112us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 83/100
# 4172/4172 [==============================] - 0s 111us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00083: ReduceLROnPlateau reducing learning rate to 3.6473000716187714e-25.
# Epoch 84/100
# 4172/4172 [==============================] - 1s 123us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 85/100
# 4172/4172 [==============================] - 0s 109us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00085: ReduceLROnPlateau reducing learning rate to 1.0941900362767734e-25.
# Epoch 86/100
# 4172/4172 [==============================] - 0s 120us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 87/100
# 4172/4172 [==============================] - 0s 111us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 00087: ReduceLROnPlateau reducing learning rate to 3.28257003487461e-26.
# Epoch 88/100
# 4172/4172 [==============================] - 0s 116us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 89/100
# 4172/4172 [==============================] - 0s 115us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00089: ReduceLROnPlateau reducing learning rate to 9.847710289513105e-27.
# Epoch 90/100
# 4172/4172 [==============================] - 0s 118us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 91/100
# 4172/4172 [==============================] - 0s 108us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00091: ReduceLROnPlateau reducing learning rate to 2.9543131330762504e-27.
# Epoch 92/100
# 4172/4172 [==============================] - 0s 109us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 93/100
# 4172/4172 [==============================] - 0s 107us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00093: ReduceLROnPlateau reducing learning rate to 8.862939514784548e-28.
# Epoch 94/100
# 4172/4172 [==============================] - 0s 115us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 95/100
# 4172/4172 [==============================] - 0s 119us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00095: ReduceLROnPlateau reducing learning rate to 2.658881969991161e-28.
# Epoch 96/100
# 4172/4172 [==============================] - 0s 108us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 97/100
# 4172/4172 [==============================] - 0s 118us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00097: ReduceLROnPlateau reducing learning rate to 7.976646198862975e-29.
# Epoch 98/100
# 4172/4172 [==============================] - 0s 117us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
# Epoch 99/100
# 4172/4172 [==============================] - 0s 118us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665
#
# Epoch 00099: ReduceLROnPlateau reducing learning rate to 2.3929938957700788e-29.
# Epoch 100/100
# 4172/4172 [==============================] - 0s 108us/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.0947 - val_accuracy: 0.9665

# %% [markdown]
# ### Это функция для получения конечного предсказания. Модель получает предсказания 5-и других моделей и затем возвращает своё

# %%
# make a prediction with the stacked model
def stacked_prediction(members, model, inputX):
	# create dataset using ensemble
	stackedX = stacked_dataset(members, inputX)
	# make a prediction
	yhat = model.predict(stackedX)
	return yhat

# %% [markdown]
# ### Измерение точности модели на наборе тестовых данных. Как видно, точность составляет почти 93%

# %%
yhat = stacked_prediction(models, model, test_data)
for i in range(len(yhat)):
    if yhat[i] > 0.95:
        yhat[i] = 1
    else:
        yhat[i] = 0
acc = accuracy_score(test_labels, yhat)
print('Stacked Test Accuracy:', (acc * 100))
# Out:
# Stacked Test Accuracy: 92.94871794871796

# %%
#Небольшой модуль для очистки видеопамяти. На всякий случай.
from numba import cuda
cuda.select_device(0)
cuda.close()
